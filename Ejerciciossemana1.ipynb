# %% [markdown]
# Ejercicio 1

# %% [markdown]
# Entrada
#
#     ◦Tener una taza o termo y dos cucharas.
#     ◦Tener cafe de su preferencia y azucar en caso de requerirla.
#     ◦El agua debe de estar a una temperatura caliente pero a su preferencia.
#     ◦La cantidad de cafe puede ser de una cucharada.
#     ◦La azucar puede ser opcional ya sea que si lleve o no, en caso de que si lleve puede ser 1 o 1½ de cucharadas.
#
# Proceso
#
#  ◦Inicio
#     1-Poner a calentar una taza de agua hasta alcanzar la temperatura deseada.
#     2-Coloca el agua en una taza o termo.
#     3-Coloca la cantidad de cafe.
#     4-

# %% [markdown]
# Ejercicio 2

# %%
print("Bienvenido, este programa te ayudara a encontrar tu IMC")
nombre=(input("Ingresa tu nombre: "))
p=float(input("¿Cual es tu peso? "))
a=float(input("¿Cual es tu altura? "))

imc= str(p/(a**2))

print("Tu indice de masa corporal ", nombre,"es: ", imc)
# Out:
# Bienvenido, este programa te ayudara a encontrar tu IMC
# Tu indice de masa corporal  jhfb es:  22.857142857142858

# %% [markdown]
# Ejercicio 3

# %% [markdown]
# Ejercicio 4

# %% [markdown]
# Ejercicio 5
# Calcular area de un circulo

# %%
print("Bienvenido, este programa te ayudara a calcular el area de un circulo")
r=float(input("¿Cual es radio del circulo? "))
a= str(3.1416*(r**2))
print("El area es: ", a)
# Out:
# Bienvenido, este programa te ayudara a calcular el area de un circulo
# El area es:  78.53999999999999

# %% [markdown]
# Ejercicio 6

# %% [markdown]
# Ejercicio 7

# %% [markdown]
# Ejercicio 8

# %%
print("Bienvenido, este programa te ayudara a convertir kilometros a millas")
k=float(input("¿Incerte los kilometros? "))
m= str(k*0.621371)
print(k,"km equivalen a: ", m, "millas")
# Out:
# Bienvenido, este programa te ayudara a convertir kilometros a millas
# 10.0 km equivalen a:  6.21371 millas
